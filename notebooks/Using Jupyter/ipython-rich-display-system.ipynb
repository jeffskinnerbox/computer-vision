# %% [markdown]
# # IPython's Rich Display System
# Jupyter Notebook can display HTML, Javascript, json and latex.
#
# If you simply want to display an image you can achieve this using the IPython.display.Image class.

# %% [markdown]
# Supported image formats in OpenCV:
# * Windows bitmap (`bmp`)
# * Portable image formats (`pbm`, `pgm`, `ppm`)
# * Sun raster (`sr`, `ras`)
# * JPEG (`jpeg`, `jpg`, `jpe`)
# * JPEG 2000 (`jp2`)
# * TIFF files (`tiff`, `tif`)
# * Portable network graphics (`png`)

# %%
from IPython.display import Image, display

base = '/home/jeff/Jupyter-Notebooks/DataSets/Images/'

listOfImageNames = ['eagle.png',
                    'Lenna.jpg',
                    'tiger.bmp']

for imageName in listOfImageNames:
    display(Image(base + imageName))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7acc0e2df0bf> in <module>()
#       8
#       9 for imageName in listOfImageNames:
# ---> 10     display(Image(base + imageName))
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1123
#    1124         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# -> 1125             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#    1126         if self.embed:
#    1127             self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the 'bmp' image format

# %% [markdown]
# But you can't handle all types of image files.
# The code below fails.

# %%
image = Image(base + 'Lenna.tif')

image

# %% [markdown]
# But you could potentially use Markdown.
#
# [alt text!](/home/jeff/Jupyter-Notebooks/images/real-time-face-tracking.gif, "Title")

# %% [markdown]
# Lest extend the capabilities with this new class.

# %%
class ImageFile(object):
    """Class for storing an image location."""

    def __init__(self, fpath):
        self.fpath = fpath
        self.format = fpath.split('.')[-1]

    def _repr_png_(self):
        if self.format == 'png':
            return open(self.fpath, 'r').read()

    def _repr_jpeg_(self):
        if self.format == 'jpeg' or self.format == 'jpg':
            return open(self.fpath, 'r').read()

    def _repr_svg_(self):
        if self.format == 'svg':
            return open(self.fpath, 'r').read()

# %% [markdown]
# ## Sources
# * [Unifying picamera and cv2.VideoCapture into a single class with OpenCV](http://www.pyimagesearch.com/2016/01/04/unifying-picamera-and-cv2-videocapture-into-a-single-class-with-opencv/)
# * [IPython's Rich Display System](http://nbviewer.jupyter.org/github/ipython/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb)
